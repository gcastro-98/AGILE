# %%
from IPython.core.display import HTML
def css_styling():   
    styles = open("styles/custom.css", "r").read() 
    return HTML(styles)

# %% [markdown]
# # 1 Introduction to MongoDB
# <small>This introduction is partially inspired on the notes of Alberto Negron's [blog](http://altons.github.io/python/2013/01/21/gentle-introduction-to-mongodb-using-pymongo/)</small>

# %% [markdown]
# MongoDB is a document-oriented database, part of the NoSQL family of database systems. MongoDB stores structured data as JSON-like structures. From a pythonic point of view it is like storing dictionary data structures. One of its main feature is its schema-less feature, i.e. it supports dynamic schemas. A schema in a relational database informally refer to the structure of the data it stores, i.e. what kind of data, which tables, which relations, etc.

# %% [markdown]
# ## Connecting with a MongoDB on the cloud
#
# + First, create an account in [https://cloud.mongodb.com/](https://cloud.mongodb.com/)
# + Build a free cluster instance of 0,5Gb
# + Create a Dabase User under Database Access, and connect to it following next code
# + Install pymongo + dnspython
#
# `pip install "pymongo[srv]"`

# %%
# One way...
import pymongo

with open('my_credentials.txt', 'r') as f:
    connect_order = f.readlines()[0].rstrip()
conn = pymongo.MongoClient(connect_order)
db = conn['test']

print("Connect order", connect_order)

# %%
# import pymongo
# try:
#     if 'conn' in globals():
#         conn.close()
#         print("Closing")
    
#     with open("credentials.txt", 'r') as f:
#         [name,password,url,dbname]=f.read().splitlines()
#         connect_order: str = "mongodb+srv://{}:{}@{}".format(name,password,url)
#     conn=pymongo.MongoClient(connect_order)
#     print ("Connected successfully!!!")
    
# except pymongo.errors.ConnectionFailure as e:
#     print ("Could not connect to MongoDB: %s" % e) 
# conn
# db = conn[dbname]
# db

# print(connect_order)

# %% [markdown]
# You can check your mongoDB database in this website:
# [https://cloud.mongodb.com/](https://cloud.mongodb.com/)

# %% [markdown]
# ### Connecting with a MongoDB database in localhost

# %% [markdown]
# First of all let us configure the MongoDB system.
#
# + Download mongoDB.
#
# https://www.mongodb.com/download-center/community
#
# + Create data directory:
#
# `sudo mkdir -p /data/db`
# + Check that the server works
#
# `sudo ./mongod --nojournal &`
#
# + Check the connection to the server:
#
# in another terminal write `mongo` , check that it does not raise any error and exit the console.
# + Close the mongo daemon (mongod).
#         You may have to kill mongod with
#
# `killall mongod`
#
#         and remove the lock on the daemon,
# `rm /data/db/mongod.lock`
#
# + Let us configure a little the data base by configuring the path of the data storage and log files. Create a [mongo.conf](./mongo.conf) file such as the one provided  and start the server using the following command:
#
# `mongod --config=./mongo.conf --nojournal &`
#
# + Install pymongo
#
# `pip install pymongo`

# %%
# import pymongo

# # Connection to Mongo DB
# try:
#     conn=pymongo.MongoClient()
#     print ("Connected successfully!!!")
# except pymongo.errors.ConnectionFailure as e:
#     print ("Could not connect to MongoDB: %s" % e) 
# conn

# %% [markdown]
# ## Accessing to / Creating database
#
# We can **create** or **access to** a database using attribute access <span style = "font-family:Courier;"> db = conn.name_db</span> or dictionary acces <span style = "font-family:Courier;"> db = conn[name_db]</span>.

# %%
#Create a database using db = conn.name_db or dictionary access db = conn['name_db']
db = conn['ADS']
print (db)
conn.list_database_names()
#Empty databases do not show!

# %% [markdown]
# A database stores a **collection**. A collection is a group of documents stored in MongoDB, and can be thought of as the equivalent of a table in a relational database. Getting a collection in PyMongo works the same as getting a database:

# %%
collection = db.edu
db.list_collection_names()
#Empty collections do not show!
# Out:
# ['edu']

# %% [markdown]
# MongoDB stores structured data as JSON-like documents, using dynamic schemas (called BSON), rather than predefined schemas. An element of data is called a document, and documents are stored in collections. One collection may have any number of documents.
#
# Compared to relational databases, we could say collections are like tables, and documents are like records. But there is one big difference: every record in a table has the same fields (with, usually, differing values) in the same order, while each document in a collection can have completely different fields from the other documents.
#
# All you really need to know when you're using Python, however, is that documents are Python dictionaries that can have strings as keys and can contain various primitive types (int, float,unicode, datetime) as well as other documents (Python dicts) and arrays (Python lists).
#
# To insert some data into MongoDB, all we need to do is create a dict and call .insert() on the collection object. Let us exemplify this process by getting some DatFrame and storing it in the collection.

# %%
import pandas as pd
df = pd.read_csv('./educ_figdp_1_Data.csv',na_values=':')
df.head(5)
# Out:
#    TIME                            GEO  \
# 0  2000  European Union (28 countries)
# 1  2001  European Union (28 countries)
# 2  2002  European Union (28 countries)
# 3  2003  European Union (28 countries)
# 4  2004  European Union (28 countries)
#
#                                             INDIC_ED  Value Flag and Footnotes
# 0  Total public expenditure on education as % of ...    NaN                NaN
# 1  Total public expenditure on education as % of ...    NaN                NaN
# 2  Total public expenditure on education as % of ...   5.00                  e
# 3  Total public expenditure on education as % of ...   5.03                  e
# 4  Total public expenditure on education as % of ...   4.95                  e

# %%
df.to_dict("records")
# Out:
# [{'TIME': 2000,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.0,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.03,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.91,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.91,
#   'Flag and Footnotes': 's'},
#  {'TIME': 2001,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.99,
#   'Flag and Footnotes': 's'},
#  {'TIME': 2002,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.0,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.91,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.93,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 's'},
#  {'TIME': 2001,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': 's'},
#  {'TIME': 2002,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.03,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.93,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.46,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.87,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.8,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.69,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.79,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.86,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.8,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.69,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.79,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'TIME': 2001,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': 's'},
#  {'TIME': 2002,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.01,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.96,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.87,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.81,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.29,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.16,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'TIME': 2001,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.97,
#   'Flag and Footnotes': 's'},
#  {'TIME': 2002,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.0,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2003,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2004,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2005,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2006,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.87,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2007,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.8,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2008,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2009,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2010,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2011,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'TIME': 2000,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'TIME': 2001,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.99,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2002,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.09,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2003,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.02,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2004,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2005,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.92,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2006,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2007,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.0,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2009,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.57,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2010,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.58,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2011,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.55,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2000,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.88,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.7,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.94,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.4,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.04,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.88,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.44,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.58,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.1,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.82,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.83,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.93,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.15,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.32,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.2,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.08,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.42,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.05,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.92,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.36,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.51,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.28,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2001,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.44,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2002,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.44,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2003,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.33,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.43,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.3,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2006,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.97,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2007,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.81,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.68,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2009,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.74,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2010,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.81,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2011,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.75,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2000,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.45,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.51,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.74,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.62,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.57,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.43,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.49,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.57,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.08,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.57,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2001,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.24,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.47,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.29,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.88,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.61,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.03,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.66,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.16,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.29,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.27,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.35,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.66,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.73,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.67,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.41,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.15,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.71,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2001,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.5,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2002,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.57,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2003,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.56,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2004,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.83,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2005,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.23,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.26,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.34,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.62,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.82,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.04,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.92,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.8,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.67,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.61,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.62,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.62,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.86,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.52,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.83,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.6,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.56,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.41,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.67,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.27,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.56,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.5,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.29,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.42,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2001,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2002,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.6,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2003,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.37,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2004,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.77,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2005,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.95,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2006,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.02,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2007,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.95,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.45,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2009,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.98,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2010,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.92,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2011,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.87,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2000,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.64,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.22,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.6,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.58,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.12,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.14,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.13,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.07,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.71,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.59,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.96,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.96,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.63,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.86,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.81,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.14,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Lithuania',
# ...
#  {'TIME': 2011,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.93,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.66,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.74,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.53,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.48,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.44,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.4,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.33,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.47,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.91,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.8,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.87,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2001,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.42,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2002,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2003,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.35,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2004,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2005,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.47,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2006,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2007,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.91,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.08,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2009,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.09,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2010,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.17,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2011,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.42,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2001,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.39,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2002,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.33,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2003,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2004,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.1,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2005,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.21,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2006,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.07,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2007,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.1,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2009,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.79,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2010,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.62,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2011,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.27,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2000,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 2.88,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.25,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.51,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.45,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.28,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.48,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'TIME': 2007,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'TIME': 2009,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.53,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.07,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.86,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.76,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.8,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.74,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.73,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.72,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.2,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.69,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'TIME': 2000,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.92,
#   'Flag and Footnotes': 'i'},
#  {'TIME': 2001,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.99,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2002,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.31,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2003,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.3,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2004,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.19,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2005,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.85,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2006,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.8,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2007,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.62,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2008,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.61,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2009,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2010,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.22,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2011,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.06,
#   'Flag and Footnotes': 'd'},
#  {'TIME': 2000,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.89,
#   'Flag and Footnotes': nan},
#  {'TIME': 2001,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.06,
#   'Flag and Footnotes': nan},
#  {'TIME': 2002,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.22,
#   'Flag and Footnotes': nan},
#  {'TIME': 2003,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'TIME': 2004,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.42,
#   'Flag and Footnotes': nan},
#  {'TIME': 2005,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.3,
#   'Flag and Footnotes': nan},
#  {'TIME': 2006,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.18,
#   'Flag and Footnotes': nan},
#  {'TIME': 2007,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'TIME': 2008,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.1,
#   'Flag and Footnotes': nan},
#  {'TIME': 2009,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.81,
#   'Flag and Footnotes': nan},
#  {'TIME': 2010,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.85,
#   'Flag and Footnotes': nan},
#  {'TIME': 2011,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.76,
#   'Flag and Footnotes': nan}]

# %%
#insert documents in the collection
collection.insert_many(df.to_dict("records"));

# %%
#Check that we have a non empty collection.
db.list_collection_names()
# Out:
# ['edu']

# %% [markdown]
# To recap, we have databases containing collections. A collection is made up of documents. Each document is made up of fields.

# %% [markdown]
# ### Retrieving data

# %%
collection.find_one() #Returns first document in the collection
# Out:
# {'_id': ObjectId('6336f2e48155fd577852080e'),
#  'TIME': 2000,
#  'GEO': 'European Union (28 countries)',
#  'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#  'Value': nan,
#  'Flag and Footnotes': nan}

# %% [markdown]
# To get more than a single document as the result of a query we use the find() method. find() returns a Cursor instance, which allows us to iterate over all matching documents.

# %%
collection.find()

# %%
[d for d in collection.find()]
# Out:
# [{'_id': ObjectId('6336f2e48155fd577852080e'),
#   'TIME': 2000,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852080f'),
#   'TIME': 2001,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520810'),
#   'TIME': 2002,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.0,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520811'),
#   'TIME': 2003,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.03,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520812'),
#   'TIME': 2004,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520813'),
#   'TIME': 2005,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520814'),
#   'TIME': 2006,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.91,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520815'),
#   'TIME': 2007,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520816'),
#   'TIME': 2008,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520817'),
#   'TIME': 2009,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520818'),
#   'TIME': 2010,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520819'),
#   'TIME': 2011,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852081a'),
#   'TIME': 2000,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.91,
#   'Flag and Footnotes': 's'},
#  {'_id': ObjectId('6336f2e48155fd577852081b'),
#   'TIME': 2001,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.99,
#   'Flag and Footnotes': 's'},
#  {'_id': ObjectId('6336f2e48155fd577852081c'),
#   'TIME': 2002,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.0,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852081d'),
#   'TIME': 2003,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852081e'),
#   'TIME': 2004,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852081f'),
#   'TIME': 2005,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520820'),
#   'TIME': 2006,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.91,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520821'),
#   'TIME': 2007,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.93,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520822'),
#   'TIME': 2008,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520823'),
#   'TIME': 2009,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520824'),
#   'TIME': 2010,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520825'),
#   'TIME': 2011,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520826'),
#   'TIME': 2000,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 's'},
#  {'_id': ObjectId('6336f2e48155fd5778520827'),
#   'TIME': 2001,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': 's'},
#  {'_id': ObjectId('6336f2e48155fd5778520828'),
#   'TIME': 2002,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.03,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520829'),
#   'TIME': 2003,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852082a'),
#   'TIME': 2004,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852082b'),
#   'TIME': 2005,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852082c'),
#   'TIME': 2006,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.93,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852082d'),
#   'TIME': 2007,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852082e'),
#   'TIME': 2008,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852082f'),
#   'TIME': 2009,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520830'),
#   'TIME': 2010,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.46,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520831'),
#   'TIME': 2011,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520832'),
#   'TIME': 2000,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520833'),
#   'TIME': 2001,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520834'),
#   'TIME': 2002,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.87,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520835'),
#   'TIME': 2003,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520836'),
#   'TIME': 2004,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.8,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520837'),
#   'TIME': 2005,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520838'),
#   'TIME': 2006,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.69,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520839'),
#   'TIME': 2007,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.79,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852083a'),
#   'TIME': 2008,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852083b'),
#   'TIME': 2009,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852083c'),
#   'TIME': 2010,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852083d'),
#   'TIME': 2011,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852083e'),
#   'TIME': 2000,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852083f'),
#   'TIME': 2001,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520840'),
#   'TIME': 2002,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.86,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520841'),
#   'TIME': 2003,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520842'),
#   'TIME': 2004,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.8,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520843'),
#   'TIME': 2005,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520844'),
#   'TIME': 2006,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.69,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520845'),
#   'TIME': 2007,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.79,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520846'),
#   'TIME': 2008,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520847'),
#   'TIME': 2009,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520848'),
#   'TIME': 2010,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520849'),
#   'TIME': 2011,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852084a'),
#   'TIME': 2000,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'_id': ObjectId('6336f2e48155fd577852084b'),
#   'TIME': 2001,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': 's'},
#  {'_id': ObjectId('6336f2e48155fd577852084c'),
#   'TIME': 2002,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.01,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852084d'),
#   'TIME': 2003,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852084e'),
#   'TIME': 2004,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.96,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852084f'),
#   'TIME': 2005,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520850'),
#   'TIME': 2006,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.87,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520851'),
#   'TIME': 2007,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.81,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520852'),
#   'TIME': 2008,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520853'),
#   'TIME': 2009,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520854'),
#   'TIME': 2010,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.29,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520855'),
#   'TIME': 2011,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.16,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520856'),
#   'TIME': 2000,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'_id': ObjectId('6336f2e48155fd5778520857'),
#   'TIME': 2001,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.97,
#   'Flag and Footnotes': 's'},
#  {'_id': ObjectId('6336f2e48155fd5778520858'),
#   'TIME': 2002,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.0,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520859'),
#   'TIME': 2003,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.04,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852085a'),
#   'TIME': 2004,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.95,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852085b'),
#   'TIME': 2005,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.89,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852085c'),
#   'TIME': 2006,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.87,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852085d'),
#   'TIME': 2007,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.8,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852085e'),
#   'TIME': 2008,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852085f'),
#   'TIME': 2009,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520860'),
#   'TIME': 2010,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520861'),
#   'TIME': 2011,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520862'),
#   'TIME': 2000,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': 'u'},
#  {'_id': ObjectId('6336f2e48155fd5778520863'),
#   'TIME': 2001,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.99,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('6336f2e48155fd5778520864'),
#   'TIME': 2002,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd5778520865'),
#   'TIME': 2003,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.02,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd5778520866'),
#   'TIME': 2004,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd5778520867'),
#   'TIME': 2005,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.92,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd5778520868'),
#   'TIME': 2006,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd5778520869'),
#   'TIME': 2007,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.0,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd577852086a'),
#   'TIME': 2008,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd577852086b'),
#   'TIME': 2009,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.57,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd577852086c'),
#   'TIME': 2010,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.58,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd577852086d'),
#   'TIME': 2011,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.55,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd577852086e'),
#   'TIME': 2000,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.88,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852086f'),
#   'TIME': 2001,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.7,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520870'),
#   'TIME': 2002,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.94,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520871'),
#   'TIME': 2003,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520872'),
#   'TIME': 2004,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.4,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520873'),
#   'TIME': 2005,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520874'),
#   'TIME': 2006,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.04,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520875'),
#   'TIME': 2007,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.88,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520876'),
#   'TIME': 2008,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.44,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520877'),
#   'TIME': 2009,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.58,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520878'),
#   'TIME': 2010,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.1,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520879'),
#   'TIME': 2011,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.82,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852087a'),
#   'TIME': 2000,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.83,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852087b'),
#   'TIME': 2001,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.93,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852087c'),
#   'TIME': 2002,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.15,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852087d'),
#   'TIME': 2003,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.32,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852087e'),
#   'TIME': 2004,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.2,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852087f'),
#   'TIME': 2005,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.08,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520880'),
#   'TIME': 2006,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.42,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520881'),
#   'TIME': 2007,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.05,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520882'),
#   'TIME': 2008,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.92,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520883'),
#   'TIME': 2009,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.36,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520884'),
#   'TIME': 2010,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520885'),
#   'TIME': 2011,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.51,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520886'),
#   'TIME': 2000,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.28,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('6336f2e48155fd5778520887'),
#   'TIME': 2001,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.44,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd5778520888'),
#   'TIME': 2002,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.44,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd5778520889'),
#   'TIME': 2003,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.33,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852088a'),
#   'TIME': 2004,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852088b'),
#   'TIME': 2005,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.3,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd577852088c'),
#   'TIME': 2006,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.97,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd577852088d'),
#   'TIME': 2007,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.81,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd577852088e'),
#   'TIME': 2008,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.68,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd577852088f'),
#   'TIME': 2009,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.74,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd5778520890'),
#   'TIME': 2010,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.81,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd5778520891'),
#   'TIME': 2011,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.75,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd5778520892'),
#   'TIME': 2000,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.45,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520893'),
#   'TIME': 2001,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.51,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520894'),
#   'TIME': 2002,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520895'),
#   'TIME': 2003,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.74,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520896'),
#   'TIME': 2004,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.62,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520897'),
#   'TIME': 2005,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.57,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520898'),
#   'TIME': 2006,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520899'),
#   'TIME': 2007,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.49,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852089a'),
#   'TIME': 2008,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.57,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852089b'),
#   'TIME': 2009,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852089c'),
#   'TIME': 2010,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.08,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852089d'),
#   'TIME': 2011,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852089e'),
#   'TIME': 2000,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.57,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('6336f2e48155fd577852089f'),
#   'TIME': 2001,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208a0'),
#   'TIME': 2002,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.47,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208a1'),
#   'TIME': 2003,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.29,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208a2'),
#   'TIME': 2004,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208a3'),
#   'TIME': 2005,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.88,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208a4'),
#   'TIME': 2006,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208a5'),
#   'TIME': 2007,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd57785208a6'),
#   'TIME': 2008,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.61,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208a7'),
#   'TIME': 2009,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.03,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208a8'),
#   'TIME': 2010,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.66,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208a9'),
#   'TIME': 2011,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.16,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208aa'),
#   'TIME': 2000,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.29,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208ab'),
#   'TIME': 2001,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208ac'),
#   'TIME': 2002,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.27,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208ad'),
#   'TIME': 2003,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.35,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208ae'),
#   'TIME': 2004,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.66,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208af'),
#   'TIME': 2005,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208b0'),
#   'TIME': 2006,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.73,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208b1'),
#   'TIME': 2007,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.92,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208b2'),
#   'TIME': 2008,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.67,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208b3'),
#   'TIME': 2009,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208b4'),
#   'TIME': 2010,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.41,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208b5'),
#   'TIME': 2011,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.15,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208b6'),
#   'TIME': 2000,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.71,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('6336f2e48155fd57785208b7'),
#   'TIME': 2001,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.5,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('6336f2e48155fd57785208b8'),
#   'TIME': 2002,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.57,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('6336f2e48155fd57785208b9'),
#   'TIME': 2003,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.56,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('6336f2e48155fd57785208ba'),
#   'TIME': 2004,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.83,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('6336f2e48155fd57785208bb'),
#   'TIME': 2005,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208bc'),
#   'TIME': 2006,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208bd'),
#   'TIME': 2007,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208be'),
#   'TIME': 2008,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208bf'),
#   'TIME': 2009,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208c0'),
#   'TIME': 2010,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208c1'),
#   'TIME': 2011,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208c2'),
#   'TIME': 2000,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208c3'),
#   'TIME': 2001,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208c4'),
#   'TIME': 2002,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208c5'),
#   'TIME': 2003,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208c6'),
#   'TIME': 2004,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208c7'),
#   'TIME': 2005,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.23,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208c8'),
#   'TIME': 2006,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.26,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208c9'),
#   'TIME': 2007,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.34,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208ca'),
#   'TIME': 2008,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.62,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208cb'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208cc'),
#   'TIME': 2010,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208cd'),
#   'TIME': 2011,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.82,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208ce'),
#   'TIME': 2000,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.04,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208cf'),
#   'TIME': 2001,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208d0'),
#   'TIME': 2002,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208d1'),
# ...
#   'Value': 4.92,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bb3'),
#   'TIME': 2008,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.67,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bb4'),
#   'TIME': 2009,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bb5'),
#   'TIME': 2010,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.41,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bb6'),
#   'TIME': 2011,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.15,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bb7'),
#   'TIME': 2000,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.71,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('6336f3308155fd5778520bb8'),
#   'TIME': 2001,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.5,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('6336f3308155fd5778520bb9'),
#   'TIME': 2002,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.57,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('6336f3308155fd5778520bba'),
#   'TIME': 2003,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.56,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('6336f3308155fd5778520bbb'),
#   'TIME': 2004,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.83,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('6336f3308155fd5778520bbc'),
#   'TIME': 2005,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bbd'),
#   'TIME': 2006,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bbe'),
#   'TIME': 2007,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bbf'),
#   'TIME': 2008,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bc0'),
#   'TIME': 2009,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bc1'),
#   'TIME': 2010,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bc2'),
#   'TIME': 2011,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bc3'),
#   'TIME': 2000,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bc4'),
#   'TIME': 2001,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bc5'),
#   'TIME': 2002,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bc6'),
#   'TIME': 2003,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bc7'),
#   'TIME': 2004,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bc8'),
#   'TIME': 2005,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.23,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bc9'),
#   'TIME': 2006,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.26,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bca'),
#   'TIME': 2007,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.34,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bcb'),
#   'TIME': 2008,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.62,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bcc'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bcd'),
#   'TIME': 2010,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bce'),
#   'TIME': 2011,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.82,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bcf'),
#   'TIME': 2000,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.04,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bd0'),
#   'TIME': 2001,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bd1'),
#   'TIME': 2002,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bd2'),
#   'TIME': 2003,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.92,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bd3'),
#   'TIME': 2004,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.8,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bd4'),
#   'TIME': 2005,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.67,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bd5'),
#   'TIME': 2006,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.61,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bd6'),
#   'TIME': 2007,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.62,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bd7'),
#   'TIME': 2008,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.62,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bd8'),
#   'TIME': 2009,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bd9'),
#   'TIME': 2010,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.86,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bda'),
#   'TIME': 2011,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bdb'),
#   'TIME': 2000,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.52,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bdc'),
#   'TIME': 2001,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.83,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bdd'),
#   'TIME': 2002,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.6,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bde'),
#   'TIME': 2003,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.72,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bdf'),
#   'TIME': 2004,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.56,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520be0'),
#   'TIME': 2005,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.41,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520be1'),
#   'TIME': 2006,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.67,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520be2'),
#   'TIME': 2007,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.27,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520be3'),
#   'TIME': 2008,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.56,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520be4'),
#   'TIME': 2009,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520be5'),
#   'TIME': 2010,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.5,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520be6'),
#   'TIME': 2011,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.29,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520be7'),
#   'TIME': 2000,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.42,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('6336f3308155fd5778520be8'),
#   'TIME': 2001,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': 'i'},
#  {'_id': ObjectId('6336f3308155fd5778520be9'),
#   'TIME': 2002,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.6,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3308155fd5778520bea'),
#   'TIME': 2003,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.37,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3308155fd5778520beb'),
#   'TIME': 2004,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.77,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3308155fd5778520bec'),
#   'TIME': 2005,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.95,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3308155fd5778520bed'),
#   'TIME': 2006,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.02,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3308155fd5778520bee'),
#   'TIME': 2007,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.95,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3308155fd5778520bef'),
#   'TIME': 2008,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.45,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3308155fd5778520bf0'),
#   'TIME': 2009,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.98,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3308155fd5778520bf1'),
#   'TIME': 2010,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.92,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3308155fd5778520bf2'),
#   'TIME': 2011,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.87,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3308155fd5778520bf3'),
#   'TIME': 2000,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.64,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bf4'),
#   'TIME': 2001,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.22,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bf5'),
#   'TIME': 2002,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.6,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bf6'),
#   'TIME': 2003,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.58,
#   'Flag and Footnotes': nan},
#  ...]

# %% [markdown]
# If we just want to know how many documents match a query we can perform a count() operation instead of a full query. We can get a count of all of the documents in a collection:

# %%
collection.count_documents({})
# Out:
# 2688

# %% [markdown]
# ### Basic queries

# %% [markdown]
# Querying in pymongo uses .find()

# %%
[d for d in collection.find({"TIME":2009})]
# Out:
# [{'_id': ObjectId('6336f2e48155fd5778520817'),
#   'TIME': 2009,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520823'),
#   'TIME': 2009,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852082f'),
#   'TIME': 2009,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852083b'),
#   'TIME': 2009,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520847'),
#   'TIME': 2009,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520853'),
#   'TIME': 2009,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852085f'),
#   'TIME': 2009,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852086b'),
#   'TIME': 2009,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.57,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd5778520877'),
#   'TIME': 2009,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.58,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520883'),
#   'TIME': 2009,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.36,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852088f'),
#   'TIME': 2009,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.74,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd577852089b'),
#   'TIME': 2009,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208a7'),
#   'TIME': 2009,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.03,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208b3'),
#   'TIME': 2009,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208bf'),
#   'TIME': 2009,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208cb'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208d7'),
#   'TIME': 2009,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208e3'),
#   'TIME': 2009,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208ef'),
#   'TIME': 2009,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.98,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd57785208fb'),
#   'TIME': 2009,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.59,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520907'),
#   'TIME': 2009,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.64,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520913'),
#   'TIME': 2009,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852091f'),
#   'TIME': 2009,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.12,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852092b'),
#   'TIME': 2009,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520937'),
#   'TIME': 2009,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520943'),
#   'TIME': 2009,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852094f'),
#   'TIME': 2009,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd577852095b'),
#   'TIME': 2009,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.79,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd5778520967'),
#   'TIME': 2009,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520973'),
#   'TIME': 2009,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.69,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852097f'),
#   'TIME': 2009,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd577852098b'),
#   'TIME': 2009,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.81,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520998'),
#   'TIME': 2009,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd57785209a4'),
#   'TIME': 2009,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd57785209b0'),
#   'TIME': 2009,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd57785209bc'),
#   'TIME': 2009,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd57785209c8'),
#   'TIME': 2009,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd57785209d4'),
#   'TIME': 2009,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd57785209e0'),
#   'TIME': 2009,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd57785209ec'),
#   'TIME': 2009,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.57,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3278155fd57785209f8'),
#   'TIME': 2009,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.58,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a04'),
#   'TIME': 2009,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.36,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a10'),
#   'TIME': 2009,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.74,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3278155fd5778520a1c'),
#   'TIME': 2009,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a28'),
#   'TIME': 2009,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.03,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a34'),
#   'TIME': 2009,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a40'),
#   'TIME': 2009,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a4c'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a58'),
#   'TIME': 2009,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a64'),
#   'TIME': 2009,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a70'),
#   'TIME': 2009,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.98,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3278155fd5778520a7c'),
#   'TIME': 2009,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.59,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a88'),
#   'TIME': 2009,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.64,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a94'),
#   'TIME': 2009,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520aa0'),
#   'TIME': 2009,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.12,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520aac'),
#   'TIME': 2009,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520ab8'),
#   'TIME': 2009,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520ac4'),
#   'TIME': 2009,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520ad0'),
#   'TIME': 2009,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3278155fd5778520adc'),
#   'TIME': 2009,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.79,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3278155fd5778520ae8'),
#   'TIME': 2009,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520af4'),
#   'TIME': 2009,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.69,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520b00'),
#   'TIME': 2009,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3278155fd5778520b0c'),
#   'TIME': 2009,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.81,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520b18'),
#   'TIME': 2009,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3308155fd5778520b24'),
#   'TIME': 2009,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3308155fd5778520b30'),
#   'TIME': 2009,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3308155fd5778520b3c'),
#   'TIME': 2009,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3308155fd5778520b48'),
#   'TIME': 2009,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3308155fd5778520b54'),
#   'TIME': 2009,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3308155fd5778520b60'),
#   'TIME': 2009,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3308155fd5778520b6c'),
#   'TIME': 2009,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.57,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3308155fd5778520b78'),
#   'TIME': 2009,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.58,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520b84'),
#   'TIME': 2009,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.36,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520b90'),
#   'TIME': 2009,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.74,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3308155fd5778520b9c'),
#   'TIME': 2009,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520ba8'),
#   'TIME': 2009,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.03,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bb4'),
#   'TIME': 2009,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bc0'),
#   'TIME': 2009,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bcc'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bd8'),
#   'TIME': 2009,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520be4'),
#   'TIME': 2009,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bf0'),
#   'TIME': 2009,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.98,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3308155fd5778520bfc'),
#   'TIME': 2009,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.59,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520c08'),
#   'TIME': 2009,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.64,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520c14'),
#   'TIME': 2009,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520c20'),
#   'TIME': 2009,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.12,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520c2c'),
#   'TIME': 2009,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520c38'),
#   'TIME': 2009,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520c44'),
#   'TIME': 2009,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520c50'),
#   'TIME': 2009,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3308155fd5778520c5c'),
#   'TIME': 2009,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.79,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3308155fd5778520c68'),
#   'TIME': 2009,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520c74'),
#   'TIME': 2009,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.69,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520c80'),
#   'TIME': 2009,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3308155fd5778520c8c'),
#   'TIME': 2009,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.81,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520c98'),
#   'TIME': 2009,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f35d8155fd5778520ca4'),
#   'TIME': 2009,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f35d8155fd5778520cb0'),
#   'TIME': 2009,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f35d8155fd5778520cbc'),
#   'TIME': 2009,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f35d8155fd5778520cc8'),
#   'TIME': 2009,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f35d8155fd5778520cd4'),
#   'TIME': 2009,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f35d8155fd5778520ce0'),
#   'TIME': 2009,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f35d8155fd5778520cec'),
#   'TIME': 2009,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.57,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f35d8155fd5778520cf8'),
#   'TIME': 2009,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.58,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520d04'),
#   'TIME': 2009,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.36,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520d10'),
#   'TIME': 2009,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.74,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f35d8155fd5778520d1c'),
#   'TIME': 2009,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520d28'),
#   'TIME': 2009,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.03,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520d34'),
#   'TIME': 2009,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520d40'),
#   'TIME': 2009,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520d4c'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520d58'),
#   'TIME': 2009,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520d64'),
#   'TIME': 2009,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520d70'),
#   'TIME': 2009,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.98,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f35d8155fd5778520d7c'),
#   'TIME': 2009,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.59,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520d88'),
#   'TIME': 2009,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.64,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520d94'),
#   'TIME': 2009,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520da0'),
#   'TIME': 2009,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.12,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520dac'),
#   'TIME': 2009,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520db8'),
#   'TIME': 2009,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520dc4'),
#   'TIME': 2009,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520dd0'),
#   'TIME': 2009,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f35d8155fd5778520ddc'),
#   'TIME': 2009,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.79,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f35d8155fd5778520de8'),
#   'TIME': 2009,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520df4'),
#   'TIME': 2009,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.69,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520e00'),
#   'TIME': 2009,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f35d8155fd5778520e0c'),
#   'TIME': 2009,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.81,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520e1a'),
#   'TIME': 2009,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f4828155fd5778520e26'),
#   'TIME': 2009,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f4828155fd5778520e32'),
#   'TIME': 2009,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f4828155fd5778520e3e'),
#   'TIME': 2009,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f4828155fd5778520e4a'),
#   'TIME': 2009,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f4828155fd5778520e56'),
#   'TIME': 2009,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f4828155fd5778520e62'),
#   'TIME': 2009,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f4828155fd5778520e6e'),
#   'TIME': 2009,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.57,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f4828155fd5778520e7a'),
#   'TIME': 2009,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.58,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520e86'),
#   'TIME': 2009,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.36,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520e92'),
#   'TIME': 2009,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.74,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f4828155fd5778520e9e'),
#   'TIME': 2009,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520eaa'),
#   'TIME': 2009,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.03,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520eb6'),
#   'TIME': 2009,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520ec2'),
#   'TIME': 2009,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520ece'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520eda'),
#   'TIME': 2009,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520ee6'),
#   'TIME': 2009,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520ef2'),
#   'TIME': 2009,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.98,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f4828155fd5778520efe'),
#   'TIME': 2009,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.59,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520f0a'),
#   'TIME': 2009,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.64,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520f16'),
#   'TIME': 2009,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520f22'),
#   'TIME': 2009,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.12,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520f2e'),
#   'TIME': 2009,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520f3a'),
#   'TIME': 2009,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520f46'),
#   'TIME': 2009,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520f52'),
#   'TIME': 2009,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f4828155fd5778520f5e'),
#   'TIME': 2009,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.79,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f4828155fd5778520f6a'),
#   'TIME': 2009,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520f76'),
#   'TIME': 2009,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.69,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520f82'),
#   'TIME': 2009,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f4828155fd5778520f8e'),
#   'TIME': 2009,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.81,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd5778520f9a'),
#   'TIME': 2009,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f4868155fd5778520fa6'),
#   'TIME': 2009,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f4868155fd5778520fb2'),
#   'TIME': 2009,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f4868155fd5778520fbe'),
#   'TIME': 2009,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f4868155fd5778520fca'),
#   'TIME': 2009,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f4868155fd5778520fd6'),
#   'TIME': 2009,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f4868155fd5778520fe2'),
#   'TIME': 2009,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f4868155fd5778520fee'),
#   'TIME': 2009,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.57,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f4868155fd5778520ffa'),
#   'TIME': 2009,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.58,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd5778521006'),
#   'TIME': 2009,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.36,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd5778521012'),
#   'TIME': 2009,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.74,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f4868155fd577852101e'),
#   'TIME': 2009,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd577852102a'),
#   'TIME': 2009,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.03,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd5778521036'),
#   'TIME': 2009,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd5778521042'),
#   'TIME': 2009,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd577852104e'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd577852105a'),
#   'TIME': 2009,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd5778521066'),
#   'TIME': 2009,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd5778521072'),
#   'TIME': 2009,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.98,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f4868155fd577852107e'),
#   'TIME': 2009,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.59,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd577852108a'),
#   'TIME': 2009,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.64,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd5778521096'),
#   'TIME': 2009,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd57785210a2'),
#   'TIME': 2009,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.12,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd57785210ae'),
#   'TIME': 2009,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd57785210ba'),
#   'TIME': 2009,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd57785210c6'),
#   'TIME': 2009,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd57785210d2'),
#   'TIME': 2009,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f4868155fd57785210de'),
#   'TIME': 2009,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.79,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f4868155fd57785210ea'),
#   'TIME': 2009,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd57785210f6'),
#   'TIME': 2009,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.69,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd5778521102'),
#   'TIME': 2009,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f4868155fd577852110e'),
#   'TIME': 2009,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.81,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd577852111b'),
#   'TIME': 2009,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f53e8155fd5778521127'),
#   'TIME': 2009,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f53e8155fd5778521133'),
#   'TIME': 2009,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f53e8155fd577852113f'),
#   'TIME': 2009,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f53e8155fd577852114b'),
#   'TIME': 2009,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f53e8155fd5778521157'),
#   'TIME': 2009,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f53e8155fd5778521163'),
#   'TIME': 2009,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f53e8155fd577852116f'),
#   'TIME': 2009,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.57,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f53e8155fd577852117b'),
#   'TIME': 2009,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.58,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521187'),
#   'TIME': 2009,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.36,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521193'),
#   'TIME': 2009,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.74,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f53e8155fd577852119f'),
#   'TIME': 2009,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211ab'),
#   'TIME': 2009,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.03,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211b7'),
#   'TIME': 2009,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211c3'),
#   'TIME': 2009,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211cf'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211db'),
#   'TIME': 2009,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211e7'),
#   'TIME': 2009,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211f3'),
#   'TIME': 2009,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.98,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f53e8155fd57785211ff'),
#   'TIME': 2009,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.59,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd577852120b'),
#   'TIME': 2009,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.64,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521217'),
#   'TIME': 2009,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521223'),
#   'TIME': 2009,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.12,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd577852122f'),
#   'TIME': 2009,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd577852123b'),
#   'TIME': 2009,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521247'),
#   'TIME': 2009,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521253'),
#   'TIME': 2009,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f53e8155fd577852125f'),
#   'TIME': 2009,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.79,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f53e8155fd577852126b'),
#   'TIME': 2009,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521277'),
#   'TIME': 2009,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.69,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521283'),
#   'TIME': 2009,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f53e8155fd577852128f'),
#   'TIME': 2009,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.81,
#   'Flag and Footnotes': nan}]

# %% [markdown]
# Observe that it finds exact matches (including data type)

# %%
[d for d in collection.find({"TIME":"2009"})]
# Out:
# []

# %%
[d for d in collection.find({"GEO":"Spain"})]
# Out:
# [{'_id': ObjectId('6336f2e48155fd57785208c2'),
#   'TIME': 2000,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208c3'),
#   'TIME': 2001,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208c4'),
#   'TIME': 2002,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208c5'),
#   'TIME': 2003,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208c6'),
#   'TIME': 2004,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208c7'),
#   'TIME': 2005,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.23,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208c8'),
#   'TIME': 2006,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.26,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208c9'),
#   'TIME': 2007,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.34,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208ca'),
#   'TIME': 2008,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.62,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208cb'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208cc'),
#   'TIME': 2010,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208cd'),
#   'TIME': 2011,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.82,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a43'),
#   'TIME': 2000,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a44'),
#   'TIME': 2001,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a45'),
#   'TIME': 2002,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a46'),
#   'TIME': 2003,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a47'),
#   'TIME': 2004,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a48'),
#   'TIME': 2005,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.23,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a49'),
#   'TIME': 2006,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.26,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a4a'),
#   'TIME': 2007,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.34,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a4b'),
#   'TIME': 2008,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.62,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a4c'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a4d'),
#   'TIME': 2010,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a4e'),
#   'TIME': 2011,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.82,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bc3'),
#   'TIME': 2000,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bc4'),
#   'TIME': 2001,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bc5'),
#   'TIME': 2002,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bc6'),
#   'TIME': 2003,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bc7'),
#   'TIME': 2004,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bc8'),
#   'TIME': 2005,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.23,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bc9'),
#   'TIME': 2006,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.26,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bca'),
#   'TIME': 2007,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.34,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bcb'),
#   'TIME': 2008,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.62,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bcc'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bcd'),
#   'TIME': 2010,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520bce'),
#   'TIME': 2011,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.82,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520d43'),
#   'TIME': 2000,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520d44'),
#   'TIME': 2001,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520d45'),
#   'TIME': 2002,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520d46'),
#   'TIME': 2003,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520d47'),
#   'TIME': 2004,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520d48'),
#   'TIME': 2005,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.23,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520d49'),
#   'TIME': 2006,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.26,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520d4a'),
#   'TIME': 2007,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.34,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520d4b'),
#   'TIME': 2008,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.62,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520d4c'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520d4d'),
#   'TIME': 2010,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f35d8155fd5778520d4e'),
#   'TIME': 2011,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.82,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520ec5'),
#   'TIME': 2000,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520ec6'),
#   'TIME': 2001,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520ec7'),
#   'TIME': 2002,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520ec8'),
#   'TIME': 2003,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520ec9'),
#   'TIME': 2004,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520eca'),
#   'TIME': 2005,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.23,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520ecb'),
#   'TIME': 2006,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.26,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520ecc'),
#   'TIME': 2007,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.34,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520ecd'),
#   'TIME': 2008,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.62,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520ece'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520ecf'),
#   'TIME': 2010,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4828155fd5778520ed0'),
#   'TIME': 2011,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.82,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd5778521045'),
#   'TIME': 2000,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd5778521046'),
#   'TIME': 2001,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd5778521047'),
#   'TIME': 2002,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd5778521048'),
#   'TIME': 2003,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.28,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd5778521049'),
#   'TIME': 2004,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd577852104a'),
#   'TIME': 2005,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.23,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd577852104b'),
#   'TIME': 2006,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.26,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd577852104c'),
#   'TIME': 2007,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.34,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd577852104d'),
#   'TIME': 2008,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.62,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd577852104e'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd577852104f'),
#   'TIME': 2010,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f4868155fd5778521050'),
#   'TIME': 2011,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.82,
#   'Flag and Footnotes': nan}]

# %%
[d for d in collection.find({"GEO":"SPAIN"})]
# Out:
# []

# %% [markdown]
# Operations include *gt* (greater than), *gte* (greater than equal), *lt* (lesser than), *lte* (lesser than equal), *ne* (not equal), *nin* (not in a list), *regex* (regular expression), *exists*, *not*, *or*, *and*, etc. Let us see some examples:

# %%
[d for d in collection.find({"TIME":{"$gte":2009}})]
# Out:
# [{'_id': ObjectId('6336f2e48155fd5778520817'),
#   'TIME': 2009,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520818'),
#   'TIME': 2010,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520819'),
#   'TIME': 2011,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520823'),
#   'TIME': 2009,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520824'),
#   'TIME': 2010,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520825'),
#   'TIME': 2011,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852082f'),
#   'TIME': 2009,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520830'),
#   'TIME': 2010,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.46,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520831'),
#   'TIME': 2011,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852083b'),
#   'TIME': 2009,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852083c'),
#   'TIME': 2010,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852083d'),
#   'TIME': 2011,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520847'),
#   'TIME': 2009,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520848'),
#   'TIME': 2010,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520849'),
#   'TIME': 2011,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520853'),
#   'TIME': 2009,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520854'),
#   'TIME': 2010,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.29,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520855'),
#   'TIME': 2011,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.16,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852085f'),
#   'TIME': 2009,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520860'),
#   'TIME': 2010,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd5778520861'),
#   'TIME': 2011,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f2e48155fd577852086b'),
#   'TIME': 2009,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.57,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd577852086c'),
#   'TIME': 2010,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.58,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd577852086d'),
#   'TIME': 2011,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.55,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd5778520877'),
#   'TIME': 2009,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.58,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520878'),
#   'TIME': 2010,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.1,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520879'),
#   'TIME': 2011,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.82,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520883'),
#   'TIME': 2009,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.36,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520884'),
#   'TIME': 2010,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520885'),
#   'TIME': 2011,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.51,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852088f'),
#   'TIME': 2009,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.74,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd5778520890'),
#   'TIME': 2010,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.81,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd5778520891'),
#   'TIME': 2011,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.75,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd577852089b'),
#   'TIME': 2009,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852089c'),
#   'TIME': 2010,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.08,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852089d'),
#   'TIME': 2011,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208a7'),
#   'TIME': 2009,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.03,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208a8'),
#   'TIME': 2010,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.66,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208a9'),
#   'TIME': 2011,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.16,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208b3'),
#   'TIME': 2009,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208b4'),
#   'TIME': 2010,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.41,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208b5'),
#   'TIME': 2011,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.15,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208bf'),
#   'TIME': 2009,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208c0'),
#   'TIME': 2010,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208c1'),
#   'TIME': 2011,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208cb'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208cc'),
#   'TIME': 2010,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208cd'),
#   'TIME': 2011,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.82,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208d7'),
#   'TIME': 2009,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208d8'),
#   'TIME': 2010,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.86,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208d9'),
#   'TIME': 2011,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208e3'),
#   'TIME': 2009,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208e4'),
#   'TIME': 2010,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.5,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208e5'),
#   'TIME': 2011,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.29,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208ef'),
#   'TIME': 2009,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.98,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd57785208f0'),
#   'TIME': 2010,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.92,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd57785208f1'),
#   'TIME': 2011,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.87,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd57785208fb'),
#   'TIME': 2009,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.59,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208fc'),
#   'TIME': 2010,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.96,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd57785208fd'),
#   'TIME': 2011,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.96,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520907'),
#   'TIME': 2009,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.64,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520908'),
#   'TIME': 2010,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.36,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520909'),
#   'TIME': 2011,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.17,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520913'),
#   'TIME': 2009,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520914'),
#   'TIME': 2010,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520915'),
#   'TIME': 2011,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852091f'),
#   'TIME': 2009,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.12,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520920'),
#   'TIME': 2010,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520921'),
#   'TIME': 2011,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.71,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852092b'),
#   'TIME': 2009,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852092c'),
#   'TIME': 2010,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.74,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852092d'),
#   'TIME': 2011,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.96,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520937'),
#   'TIME': 2009,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520938'),
#   'TIME': 2010,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520939'),
#   'TIME': 2011,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.93,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520943'),
#   'TIME': 2009,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520944'),
#   'TIME': 2010,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.91,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520945'),
#   'TIME': 2011,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.8,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852094f'),
#   'TIME': 2009,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd5778520950'),
#   'TIME': 2010,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.17,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd5778520951'),
#   'TIME': 2011,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852095b'),
#   'TIME': 2009,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.79,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd577852095c'),
#   'TIME': 2010,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.62,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd577852095d'),
#   'TIME': 2011,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.27,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd5778520967'),
#   'TIME': 2009,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520968'),
#   'TIME': 2010,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.53,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520969'),
#   'TIME': 2011,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.07,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520973'),
#   'TIME': 2009,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.69,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520974'),
#   'TIME': 2010,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd5778520975'),
#   'TIME': 2011,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852097f'),
#   'TIME': 2009,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd5778520980'),
#   'TIME': 2010,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.22,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd5778520981'),
#   'TIME': 2011,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.06,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f2e48155fd577852098b'),
#   'TIME': 2009,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.81,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852098c'),
#   'TIME': 2010,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.85,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f2e48155fd577852098d'),
#   'TIME': 2011,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.76,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520998'),
#   'TIME': 2009,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd5778520999'),
#   'TIME': 2010,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd577852099a'),
#   'TIME': 2011,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd57785209a4'),
#   'TIME': 2009,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd57785209a5'),
#   'TIME': 2010,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd57785209a6'),
#   'TIME': 2011,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd57785209b0'),
#   'TIME': 2009,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd57785209b1'),
#   'TIME': 2010,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.46,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd57785209b2'),
#   'TIME': 2011,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd57785209bc'),
#   'TIME': 2009,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd57785209bd'),
#   'TIME': 2010,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd57785209be'),
#   'TIME': 2011,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd57785209c8'),
#   'TIME': 2009,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.31,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd57785209c9'),
#   'TIME': 2010,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd57785209ca'),
#   'TIME': 2011,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd57785209d4'),
#   'TIME': 2009,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd57785209d5'),
#   'TIME': 2010,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.29,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd57785209d6'),
#   'TIME': 2011,
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.16,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd57785209e0'),
#   'TIME': 2009,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd57785209e1'),
#   'TIME': 2010,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.28,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd57785209e2'),
#   'TIME': 2011,
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.15,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3278155fd57785209ec'),
#   'TIME': 2009,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.57,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3278155fd57785209ed'),
#   'TIME': 2010,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.58,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3278155fd57785209ee'),
#   'TIME': 2011,
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.55,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3278155fd57785209f8'),
#   'TIME': 2009,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.58,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd57785209f9'),
#   'TIME': 2010,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.1,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd57785209fa'),
#   'TIME': 2011,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.82,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a04'),
#   'TIME': 2009,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.36,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a05'),
#   'TIME': 2010,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a06'),
#   'TIME': 2011,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.51,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a10'),
#   'TIME': 2009,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.74,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3278155fd5778520a11'),
#   'TIME': 2010,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.81,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3278155fd5778520a12'),
#   'TIME': 2011,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.75,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3278155fd5778520a1c'),
#   'TIME': 2009,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a1d'),
#   'TIME': 2010,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.08,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a1e'),
#   'TIME': 2011,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a28'),
#   'TIME': 2009,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.03,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a29'),
#   'TIME': 2010,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.66,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a2a'),
#   'TIME': 2011,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.16,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a34'),
#   'TIME': 2009,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a35'),
#   'TIME': 2010,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.41,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a36'),
#   'TIME': 2011,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.15,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a40'),
#   'TIME': 2009,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a41'),
#   'TIME': 2010,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a42'),
#   'TIME': 2011,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a4c'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a4d'),
#   'TIME': 2010,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a4e'),
#   'TIME': 2011,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.82,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a58'),
#   'TIME': 2009,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a59'),
#   'TIME': 2010,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.86,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a5a'),
#   'TIME': 2011,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a64'),
#   'TIME': 2009,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a65'),
#   'TIME': 2010,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.5,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a66'),
#   'TIME': 2011,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.29,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a70'),
#   'TIME': 2009,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.98,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3278155fd5778520a71'),
#   'TIME': 2010,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.92,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3278155fd5778520a72'),
#   'TIME': 2011,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.87,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3278155fd5778520a7c'),
#   'TIME': 2009,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.59,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a7d'),
#   'TIME': 2010,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.96,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a7e'),
#   'TIME': 2011,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.96,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a88'),
#   'TIME': 2009,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.64,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a89'),
#   'TIME': 2010,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.36,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a8a'),
#   'TIME': 2011,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.17,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a94'),
#   'TIME': 2009,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a95'),
#   'TIME': 2010,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520a96'),
#   'TIME': 2011,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520aa0'),
#   'TIME': 2009,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.12,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520aa1'),
#   'TIME': 2010,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520aa2'),
#   'TIME': 2011,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.71,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520aac'),
#   'TIME': 2009,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520aad'),
#   'TIME': 2010,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.74,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520aae'),
#   'TIME': 2011,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.96,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520ab8'),
#   'TIME': 2009,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520ab9'),
#   'TIME': 2010,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520aba'),
#   'TIME': 2011,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.93,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520ac4'),
#   'TIME': 2009,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520ac5'),
#   'TIME': 2010,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.91,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520ac6'),
#   'TIME': 2011,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.8,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520ad0'),
#   'TIME': 2009,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3278155fd5778520ad1'),
#   'TIME': 2010,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.17,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3278155fd5778520ad2'),
#   'TIME': 2011,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520adc'),
#   'TIME': 2009,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.79,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3278155fd5778520add'),
#   'TIME': 2010,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.62,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3278155fd5778520ade'),
#   'TIME': 2011,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.27,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3278155fd5778520ae8'),
#   'TIME': 2009,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520ae9'),
#   'TIME': 2010,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.53,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520aea'),
#   'TIME': 2011,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.07,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520af4'),
#   'TIME': 2009,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.69,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520af5'),
#   'TIME': 2010,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520af6'),
#   'TIME': 2011,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520b00'),
#   'TIME': 2009,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3278155fd5778520b01'),
#   'TIME': 2010,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.22,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3278155fd5778520b02'),
#   'TIME': 2011,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.06,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f3278155fd5778520b0c'),
#   'TIME': 2009,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.81,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520b0d'),
#   'TIME': 2010,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.85,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3278155fd5778520b0e'),
#   'TIME': 2011,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.76,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f3308155fd5778520b18'),
#   'TIME': 2009,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3308155fd5778520b19'),
#   'TIME': 2010,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3308155fd5778520b1a'),
#   'TIME': 2011,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3308155fd5778520b24'),
#   'TIME': 2009,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.38,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3308155fd5778520b25'),
#   'TIME': 2010,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3308155fd5778520b26'),
#   'TIME': 2011,
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.25,
#   'Flag and Footnotes': 'e'},
#  {'_id': ObjectId('6336f3308155fd5778520b30'),
#   'TIME': 2009,
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.41,
#   'Flag and Footnotes': 'e'},
# ...
#   'Value': 4.25,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521189'),
#   'TIME': 2011,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.51,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521193'),
#   'TIME': 2009,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.74,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f53e8155fd5778521194'),
#   'TIME': 2010,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.81,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f53e8155fd5778521195'),
#   'TIME': 2011,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 8.75,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f53e8155fd577852119f'),
#   'TIME': 2009,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.06,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211a0'),
#   'TIME': 2010,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.08,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211a1'),
#   'TIME': 2011,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211ab'),
#   'TIME': 2009,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.03,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211ac'),
#   'TIME': 2010,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.66,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211ad'),
#   'TIME': 2011,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.16,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211b7'),
#   'TIME': 2009,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.43,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211b8'),
#   'TIME': 2010,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.41,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211b9'),
#   'TIME': 2011,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.15,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211c3'),
#   'TIME': 2009,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211c4'),
#   'TIME': 2010,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211c5'),
#   'TIME': 2011,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211cf'),
#   'TIME': 2009,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.02,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211d0'),
#   'TIME': 2010,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211d1'),
#   'TIME': 2011,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.82,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211db'),
#   'TIME': 2009,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211dc'),
#   'TIME': 2010,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.86,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211dd'),
#   'TIME': 2011,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211e7'),
#   'TIME': 2009,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.7,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211e8'),
#   'TIME': 2010,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.5,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211e9'),
#   'TIME': 2011,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.29,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd57785211f3'),
#   'TIME': 2009,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.98,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f53e8155fd57785211f4'),
#   'TIME': 2010,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.92,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f53e8155fd57785211f5'),
#   'TIME': 2011,
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.87,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f53e8155fd57785211ff'),
#   'TIME': 2009,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.59,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521200'),
#   'TIME': 2010,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.96,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521201'),
#   'TIME': 2011,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.96,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd577852120b'),
#   'TIME': 2009,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.64,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd577852120c'),
#   'TIME': 2010,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.36,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd577852120d'),
#   'TIME': 2011,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.17,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521217'),
#   'TIME': 2009,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521218'),
#   'TIME': 2010,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521219'),
#   'TIME': 2011,
#   'GEO': 'Luxembourg',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': nan,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521223'),
#   'TIME': 2009,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.12,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521224'),
#   'TIME': 2010,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.9,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521225'),
#   'TIME': 2011,
#   'GEO': 'Hungary',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.71,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd577852122f'),
#   'TIME': 2009,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.32,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521230'),
#   'TIME': 2010,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.74,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521231'),
#   'TIME': 2011,
#   'GEO': 'Malta',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 7.96,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd577852123b'),
#   'TIME': 2009,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.95,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd577852123c'),
#   'TIME': 2010,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd577852123d'),
#   'TIME': 2011,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.93,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521247'),
#   'TIME': 2009,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.98,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521248'),
#   'TIME': 2010,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.91,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521249'),
#   'TIME': 2011,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.8,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521253'),
#   'TIME': 2009,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f53e8155fd5778521254'),
#   'TIME': 2010,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.17,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f53e8155fd5778521255'),
#   'TIME': 2011,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.94,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd577852125f'),
#   'TIME': 2009,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.79,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f53e8155fd5778521260'),
#   'TIME': 2010,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.62,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f53e8155fd5778521261'),
#   'TIME': 2011,
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.27,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f53e8155fd577852126b'),
#   'TIME': 2009,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.24,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd577852126c'),
#   'TIME': 2010,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.53,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd577852126d'),
#   'TIME': 2011,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 3.07,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521277'),
#   'TIME': 2009,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.69,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521278'),
#   'TIME': 2010,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521279'),
#   'TIME': 2011,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 5.68,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521283'),
#   'TIME': 2009,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.09,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f53e8155fd5778521284'),
#   'TIME': 2010,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.22,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f53e8155fd5778521285'),
#   'TIME': 2011,
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 4.06,
#   'Flag and Footnotes': 'd'},
#  {'_id': ObjectId('6336f53e8155fd577852128f'),
#   'TIME': 2009,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.81,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521290'),
#   'TIME': 2010,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.85,
#   'Flag and Footnotes': nan},
#  {'_id': ObjectId('6336f53e8155fd5778521291'),
#   'TIME': 2011,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'Value': 6.76,
#   'Flag and Footnotes': nan}]

# %%
substring = r'Euro'
reg = substring
[(i["GEO"]) for i in collection.find({"GEO":{"$regex":reg}})]
# Out:
# ['European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (28 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (27 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'European Union (25 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (18 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (17 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (15 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)',
#  'Euro area (13 countries)']

# %%
for item in collection.find({"GEO":{"$regex":reg}}):
     print (item['GEO'])
# Out:
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)

# %% [markdown]
# ### Update

# %% [markdown]
# In this section, several methods for updating and deleting documents are reveiwed:
#
# + Replace. This method finds the documents defined by query and **replaces** it by the new document.

# %%
#Insert One new Document
import numpy as np
doc = {'Flag and Footnotes': np.nan,
  'GEO': 'Catalunya',
  'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
  'TIME': 2017,
  'Value': np.nan}
collection.insert_one(doc)

# %%
for doc in collection.find({'GEO':"Catalunya"}):
    print (doc)
# Out:
# {'_id': ObjectId('6154507e22ce1956b4fc36ad'), 'Flag and Footnotes': nan, 'GEO': 'Catalunya', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'TIME': 2017, 'Value': nan}

# %%
#Replace first occurence
newdoc = {'Flag and Footnotes': np.nan,
  'GEO': 'Catalunya',
  'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
  'TIME': 2017,
  'Value': 15}
collection.replace_one({'GEO':"Catalunya"},newdoc)

for doc in collection.find({'GEO':"Catalunya"}):
    print (doc)
# Out:
# {'_id': ObjectId('6154507e22ce1956b4fc36ad'), 'Flag and Footnotes': nan, 'GEO': 'Catalunya', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'TIME': 2017, 'Value': 15}

# %% [markdown]
# If we don't want to write again all the document and just put the field that we want to change then we have to use **update_one** and adding a sub-command.  Let us check some of them:

# %% [markdown]
# + Sub-command **Set**:
#
# This statement updates in the document in collection where field matches value1 by replacing the value of the field field1 with value2. This operator will add the specified field or fields if they do not exist in this document or replace the existing value of the specified field(s) if they already exist.
#
# An upsert eliminates the need to perform a separate database call to check for the existence of a record before performing either an update or an insert operation. Typically update operations update existing documents, but in MongoDB, the update_one() operation can accept an upsert option as an argument. Upserts are a hybrid operation that use the query argument to determine the write operation:
#
# If the query matches an existing document(s), the upsert performs an update.
# If the query matches no document in the collection, the upsert inserts a single document.

# %%
#Update first occurrence
collection.update_one({'GEO':"Catalunya"},{"$set":{"Value":12}})

# %%
for doc in collection.find({'GEO':"Catalunya"}):
    print (doc)
# Out:
# {'_id': ObjectId('6154507e22ce1956b4fc36ad'), 'Flag and Footnotes': nan, 'GEO': 'Catalunya', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'TIME': 2017, 'Value': 12}

# %% [markdown]
# By default, if the filter doesn't return any document, nothing is inserted to database. If you want to insert it, then set the upsert flag to `True`

# %%
collection.update_one({'GEO':"Andorra"},{"$set":{"Value":12}},upsert = True)
for doc in collection.find({'GEO':"Andorra"}):
    print (doc)
# Out:
# {'_id': ObjectId('6154512dd87047bf2b704a8d'), 'GEO': 'Andorra', 'Value': 12}

# %% [markdown]
# + Sub-commnad **Unset**:
#
# The unset operator deletes a particular field. If documents match the initial query but do not have the field specified in the unset operation, there the statement has no effect on the document.

# %%
collection.update_one({'GEO':"Catalunya"},{"$unset":{"Flag and Footnotes":""}})

# %%
for doc in collection.find({'GEO':"Catalunya"}):
    print (doc)
# Out:
# {'_id': ObjectId('6154507e22ce1956b4fc36ad'), 'GEO': 'Catalunya', 'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined', 'TIME': 2017, 'Value': 12}

# %% [markdown]
# ### Delete operations

# %% [markdown]
# We can remove elements by simply:

# %%
collection.delete_one({"GEO":"Andorra"})

# %%
for doc in collection.find({"GEO":"Andorra"}):
    print (doc)

# %% [markdown]
# And remove a collection by:

# %%
db.list_collection_names()
# Out:
# ['edu']

# %%
db.drop_collection("edu")
db.list_collection_names()
# Out:
# []

# %% [markdown]
# And remove a database by:

# %%
conn.list_database_names()
# Out:
# ['admin', 'local']

# %%
conn.drop_database('ads')
conn.list_database_names()
# Out:
# ['admin', 'local']

# %% [markdown]
# And finally close the connection with the database.

# %%
conn.close()
